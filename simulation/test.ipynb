# %%
from distribution import *

# %%
build_nodes('segment')
# Out:
# [Node(name='p1_r1_segment', provider='p1', region='r1', can_store=True, llm_option=None),
#  Node(name='p1_r2_segment', provider='p1', region='r2', can_store=True, llm_option=None),
#  Node(name='p1_r3_segment', provider='p1', region='r3', can_store=True, llm_option=None),
#  Node(name='p1_r4_segment', provider='p1', region='r4', can_store=True, llm_option=None),
#  Node(name='p2_r1_segment', provider='p2', region='r1', can_store=True, llm_option=None),
#  Node(name='p2_r2_segment', provider='p2', region='r2', can_store=True, llm_option=None),
#  Node(name='p2_r5_segment', provider='p2', region='r5', can_store=True, llm_option=None),
#  Node(name='p2_r6_segment', provider='p2', region='r6', can_store=True, llm_option=None),
#  Node(name='p3_r3_segment', provider='p3', region='r3', can_store=True, llm_option=None),
#  Node(name='p3_r4_segment', provider='p3', region='r4', can_store=True, llm_option=None),
# ...

# %%
get_data_size_mb()
# Out:
# 321.51626523665243

# %%
get_data_conversion_ratio('split')
# Out:
# 0.9988761455245119

# %%
m = build_comm_matrix()
rtt, bw = m.link("p1_r1", "p2_r1")
print(rtt, bw)
# 或者 rtt, bw = m.link(0, 3)
# Out:
# 7.1964393220092004 1155.2035470611047
